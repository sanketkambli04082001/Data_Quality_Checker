# %% [markdown]
# # Data Cleaning Exploration
# ## Part 1: Core Cleaning Steps
# ---

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df
# Out:
#     employee_id           name  age department  gender   salary  joining_year  \
# 0           101    Amit Sharma   28      Sales    Male  45000.0          2019
# 1           102    Priya Patel   34         HR  Female  52000.0          2017
# 2           103    Rohit Mehta   -5      Sales    male      NaN          2021
# 3           104    Sneha Joshi   29         IT  FEMALE  61000.0          2020
# 4           105    Karan Desai   45    Finance    Male  75000.0          2016
# 5           106  Neha Kulkarni   31         HR  female  48000.0          2018
# 6           107   Vikram Singh   27      Sales    MALE      NaN          2022
# 7           108     Ananya Rao  999         IT  Female  90000.0          2015
# 8           109    Suresh Nair   38    Finance    male  82000.0          2019
# 9           110     Pooja Iyer   26      Sales  Female  43000.0          2023
# 10          111    Arjun Gupta   33         HR    Male  55000.0          2020
# ...

# %%
df.dtypes
# Out:
# employee_id            int64
# name                     str
# age                    int64
# department               str
# gender                   str
# salary               float64
# joining_year           int64
# performance_score    float64
# city                     str
# dtype: object

# %%
df.shape
# Out:
# (17, 9)

# %%
df.isnull().any()
# Out:
# employee_id          False
# name                 False
# age                  False
# department           False
# gender               False
# salary                True
# joining_year         False
# performance_score     True
# city                  True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# employee_id          0
# name                 0
# age                  0
# department           0
# gender               0
# salary               3
# joining_year         0
# performance_score    2
# city                 2
# dtype: int64

# %%
df['salary']
# Out:
# 0     45000.0
# 1     52000.0
# 2         NaN
# 3     61000.0
# 4     75000.0
# 5     48000.0
# 6         NaN
# 7     90000.0
# 8     82000.0
# 9     43000.0
# 10    55000.0
# 11    70000.0
# 12    67000.0
# 13    49000.0
# 14    95000.0
# 15        NaN
# 16    90000.0
# Name: salary, dtype: float64

# %%
df['salary'] = round(df['salary'].fillna(df['salary'].mean()))
df['salary']
# Out:
# 0     45000.0
# 1     52000.0
# 2     65857.0
# 3     61000.0
# 4     75000.0
# 5     48000.0
# 6     65857.0
# 7     90000.0
# 8     82000.0
# 9     43000.0
# 10    55000.0
# 11    70000.0
# 12    67000.0
# 13    49000.0
# 14    95000.0
# 15    65857.0
# 16    90000.0
# Name: salary, dtype: float64

# %%
df['performance_score']
# Out:
# 0     8.2
# 1     7.5
# 2     6.9
# 3     NaN
# 4     9.1
# 5     7.8
# 6     8.5
# 7     NaN
# 8     7.2
# 9     8.9
# 10    6.5
# 11    9.3
# 12    7.1
# 13    8.0
# 14    9.8
# 15    6.9
# 16    8.5
# Name: performance_score, dtype: float64

# %%
df['performance_score'] = df['performance_score'].fillna(df['performance_score'].mean())
df['performance_score'] = df['performance_score'].round(1)
df['performance_score']
# Out:
# 0     8.2
# 1     7.5
# 2     6.9
# 3     8.0
# 4     9.1
# 5     7.8
# 6     8.5
# 7     8.0
# 8     7.2
# 9     8.9
# 10    6.5
# 11    9.3
# 12    7.1
# 13    8.0
# 14    9.8
# 15    6.9
# 16    8.5
# Name: performance_score, dtype: float64

# %%
df['city'] = df['city'].fillna(df['city'].mode()[0])
df['city']
# Out:
# 0        Mumbai
# 1         Delhi
# 2        Mumbai
# 3        Mumbai
# 4     Bangalore
# 5          Pune
# 6        Mumbai
# 7     Hyderabad
# 8       Chennai
# 9        Mumbai
# 10       Mumbai
# 11    Bangalore
# 12        Delhi
# 13         Pune
# 14       Mumbai
# 15       Mumbai
# 16    Hyderabad
# Name: city, dtype: str

# %%
df
# Out:
#     employee_id           name  age department  gender   salary  joining_year  \
# 0           101    Amit Sharma   28      Sales    Male  45000.0          2019
# 1           102    Priya Patel   34         HR  Female  52000.0          2017
# 2           103    Rohit Mehta   -5      Sales    male  65857.0          2021
# 3           104    Sneha Joshi   29         IT  FEMALE  61000.0          2020
# 4           105    Karan Desai   45    Finance    Male  75000.0          2016
# 5           106  Neha Kulkarni   31         HR  female  48000.0          2018
# 6           107   Vikram Singh   27      Sales    MALE  65857.0          2022
# 7           108     Ananya Rao  999         IT  Female  90000.0          2015
# 8           109    Suresh Nair   38    Finance    male  82000.0          2019
# 9           110     Pooja Iyer   26      Sales  Female  43000.0          2023
# 10          111    Arjun Gupta   33         HR    Male  55000.0          2020
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#     employee_id           name  age department  gender   salary  joining_year  \
# 0           101    Amit Sharma   28      Sales    Male  45000.0          2019
# 1           102    Priya Patel   34         HR  Female  52000.0          2017
# 2           103    Rohit Mehta   -5      Sales    male  65857.0          2021
# 3           104    Sneha Joshi   29         IT  FEMALE  61000.0          2020
# 4           105    Karan Desai   45    Finance    Male  75000.0          2016
# 5           106  Neha Kulkarni   31         HR  female  48000.0          2018
# 6           107   Vikram Singh   27      Sales    MALE  65857.0          2022
# 7           108     Ananya Rao  999         IT  Female  90000.0          2015
# 8           109    Suresh Nair   38    Finance    male  82000.0          2019
# 9           110     Pooja Iyer   26      Sales  Female  43000.0          2023
# 10          111    Arjun Gupta   33         HR    Male  55000.0          2020
# ...

# %%
df.shape
# Out:
# (16, 9)

# %%
Q1 = df['age'].quantile(0.25)
Q1
# Out:
# np.float64(28.75)

# %%
Q3 = df['age'].quantile(0.75)
Q3
# Out:
# np.float64(42.0)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(13.25)

# %%
lower_bound = Q1 - (1.5*IQR)
lower_bound
# Out:
# np.float64(8.875)

# %%
upper_bound = Q3 + (1.5*IQR)
upper_bound
# Out:
# np.float64(61.875)

# %%
df
# Out:
#     employee_id           name  age department  gender   salary  joining_year  \
# 0           101    Amit Sharma   28      Sales    Male  45000.0          2019
# 1           102    Priya Patel   34         HR  Female  52000.0          2017
# 2           103    Rohit Mehta   -5      Sales    male  65857.0          2021
# 3           104    Sneha Joshi   29         IT  FEMALE  61000.0          2020
# 4           105    Karan Desai   45    Finance    Male  75000.0          2016
# 5           106  Neha Kulkarni   31         HR  female  48000.0          2018
# 6           107   Vikram Singh   27      Sales    MALE  65857.0          2022
# 7           108     Ananya Rao  999         IT  Female  90000.0          2015
# 8           109    Suresh Nair   38    Finance    male  82000.0          2019
# 9           110     Pooja Iyer   26      Sales  Female  43000.0          2023
# 10          111    Arjun Gupta   33         HR    Male  55000.0          2020
# ...

# %%
age_median = round(df['age'].median())
age_median
# Out:
# 34

# %%
outliers = (df['age'] < lower_bound) | (df['age'] > upper_bound)
outliers
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 16     True
# Name: age, dtype: bool

# %%
df.loc[outliers,'age'] = age_median

# %%
df
# Out:
#     employee_id           name  age department  gender   salary  joining_year  \
# 0           101    Amit Sharma   28      Sales    Male  45000.0          2019
# 1           102    Priya Patel   34         HR  Female  52000.0          2017
# 2           103    Rohit Mehta   34      Sales    male  65857.0          2021
# 3           104    Sneha Joshi   29         IT  FEMALE  61000.0          2020
# 4           105    Karan Desai   45    Finance    Male  75000.0          2016
# 5           106  Neha Kulkarni   31         HR  female  48000.0          2018
# 6           107   Vikram Singh   27      Sales    MALE  65857.0          2022
# 7           108     Ananya Rao   34         IT  Female  90000.0          2015
# 8           109    Suresh Nair   38    Finance    male  82000.0          2019
# 9           110     Pooja Iyer   26      Sales  Female  43000.0          2023
# 10          111    Arjun Gupta   33         HR    Male  55000.0          2020
# ...

# %%
df['gender'] = df['gender'].str.title()
df
# Out:
#     employee_id           name  age department  gender   salary  joining_year  \
# 0           101    Amit Sharma   28      Sales    Male  45000.0          2019
# 1           102    Priya Patel   34         HR  Female  52000.0          2017
# 2           103    Rohit Mehta   34      Sales    Male  65857.0          2021
# 3           104    Sneha Joshi   29         IT  Female  61000.0          2020
# 4           105    Karan Desai   45    Finance    Male  75000.0          2016
# 5           106  Neha Kulkarni   31         HR  Female  48000.0          2018
# 6           107   Vikram Singh   27      Sales    Male  65857.0          2022
# 7           108     Ananya Rao   34         IT  Female  90000.0          2015
# 8           109    Suresh Nair   38    Finance    Male  82000.0          2019
# 9           110     Pooja Iyer   26      Sales  Female  43000.0          2023
# 10          111    Arjun Gupta   33         HR    Male  55000.0          2020
# ...

# %%
df['gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %% [markdown]
# ---
# ## Part 2: Advanced Cleaning Techniques
# ---

# %%
import pandas as pd
import numpy as np

# Load the messy data
df = pd.read_csv('sample_datasets/marketing_campaign_data_messy.csv')

print(f"Loaded Dataset: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Loaded Dataset: 2020 rows, 12 columns

# %%
df
# Out:
#       Campaign_ID              Campaign_Name           Start_Date    End_Date  \
# 0        CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1        CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2        CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3        CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4        CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
# ...            ...                       ...                  ...         ...
# 2015     CMP-00400       Q3_Summer_CMP-00400  2023-10-31 00:00:00  2023-11-13
# 2016     CMP-01255       Q4_Summer_CMP-01255  2023-09-01 00:00:00  2023-09-26
# 2017     CMP-01050       Q2_Launch_CMP-01050  2023-02-09 00:00:00  2023-02-21
# 2018     CMP-01118       Q4_Winter_CMP-01118  2023-03-30 00:00:00  2023-04-27
# 2019     CMP-01554       Q4_Launch_CMP-01554  2023-06-26 00:00:00  2023-07-09
#
# ...

# %%
# HEADER CLEANING


print(df.columns.tolist())

df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

print("FIX APPLIED")
print(df.columns.tolist())
# Out:
# [' Campaign_ID ', 'Campaign_Name', 'Start_Date', 'End_Date', 'Channel', 'Impressions', 'Clicks ', 'Spend', 'Conversions', 'Active', 'Clicks', 'Campaign_Tag']
# FIX APPLIED
# ['campaign_id', 'campaign_name', 'start_date', 'end_date', 'channel', 'impressions', 'clicks', 'spend', 'conversions', 'active', 'clicks', 'campaign_tag']

# %%
# TYPE CONVERSION & CURRENCY CLEANING

dirty_spend_mask = df['spend'].astype(str).str.contains(r'\$')
print(df.loc[dirty_spend_mask,['campaign_id','spend']].head(3))

df['spend'] = df['spend'].astype(str).str.replace(r'[^\d.-]', '', regex=True)
df['spend'] = pd.to_numeric(df['spend'])

print("FIX APPLIED")
print(df.loc[dirty_spend_mask,['campaign_id','spend']].head(3))
# Out:
#    campaign_id     spend
# 0    CMP-00001   $102.82
# 21   CMP-00022   $2428.4
# 22   CMP-00023  $4726.22
# FIX APPLIED
#    campaign_id    spend
# 0    CMP-00001   102.82
# 21   CMP-00022  2428.40
# 22   CMP-00023  4726.22

# %%
# DATE PARSING


print(df['start_date'].dtype)

df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['end_date'] = pd.to_datetime(df['end_date'], dayfirst=True, errors='coerce')

print("FIX APPLIED")
print(df['start_date'].dtype)
# Out:
# str
# FIX APPLIED
# datetime64[us]
# C:\Users\ACER\AppData\Local\Temp\ipykernel_256\877702922.py:8: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df['end_date'] = pd.to_datetime(df['end_date'], dayfirst=True, errors='coerce')

# %%
df = df.loc[:, ~df.columns.duplicated()]

# %%
df
# Out:
#      campaign_id             campaign_name start_date   end_date     channel  \
# 0      CMP-00001       Q4_Summer_CMP-00001 2023-11-24 2023-12-13      TikTok
# 1      CMP-00002       Q1_Launch_CMP-00002 2023-05-06 2023-05-12    Facebook
# 2      CMP-00003       Q3_Winter_CMP-00003 2023-12-13 2023-12-20       Email
# 3      CMP-00004  Q1_BlackFriday_CMP-00004        NaT 2023-11-03      TikTok
# 4      CMP-00005       Q2_Winter_CMP-00005 2023-04-22 2023-04-23    Facebook
# ...          ...                       ...        ...        ...         ...
# 2015   CMP-00400       Q3_Summer_CMP-00400 2023-10-31 2023-11-13      TikTok
# 2016   CMP-01255       Q4_Summer_CMP-01255 2023-09-01 2023-09-26  Google Ads
# 2017   CMP-01050       Q2_Launch_CMP-01050 2023-02-09 2023-02-21   Instagram
# 2018   CMP-01118       Q4_Winter_CMP-01118 2023-03-30 2023-04-27    Facebook
# 2019   CMP-01554       Q4_Launch_CMP-01554 2023-06-26 2023-07-09       Email
#
# ...

# %%
# HANDLING OUTLIERS (WINSORIZING)


Q1 = df['spend'].quantile(0.25)
Q3 = df['spend'].quantile(0.75)

IQR = Q3 - Q1
upper_limit = Q3 + (3 * IQR)

outlier_mask = df['spend'] > upper_limit
print(df.loc[outlier_mask,['campaign_id','spend']].head(3))

print("FIX APPLIED")
df.loc[outlier_mask, 'spend'] = upper_limit
print(df.loc[outlier_mask,['campaign_id','spend']].head(3))
# Out:
#      campaign_id      spend
# 789    CMP-00790  500000.00
# 1443   CMP-01444    8921.51
# 1460   CMP-01461  500000.00
# FIX APPLIED
#      campaign_id      spend
# 789    CMP-00790  8603.5375
# 1443   CMP-01444  8603.5375
# 1460   CMP-01461  8603.5375

# %%
df.head(50)
# Out:
#    campaign_id             campaign_name start_date   end_date     channel  \
# 0    CMP-00001       Q4_Summer_CMP-00001 2023-11-24 2023-12-13      TikTok
# 1    CMP-00002       Q1_Launch_CMP-00002 2023-05-06 2023-05-12    Facebook
# 2    CMP-00003       Q3_Winter_CMP-00003 2023-12-13 2023-12-20       Email
# 3    CMP-00004  Q1_BlackFriday_CMP-00004        NaT 2023-11-03      TikTok
# 4    CMP-00005       Q2_Winter_CMP-00005 2023-04-22 2023-04-23    Facebook
# 5    CMP-00006  Q4_BlackFriday_CMP-00006 2023-10-15 2023-10-28   Instagram
# 6    CMP-00007       Q3_Launch_CMP-00007 2023-10-07 2023-10-23    Facebook
# 7    CMP-00008       Q4_Launch_CMP-00008        NaT 2023-05-28   Instagram
# 8    CMP-00009  Q4_BlackFriday_CMP-00009 2023-03-23 2023-04-01  Google Ads
# 9    CMP-00010       Q2_Winter_CMP-00010 2023-03-21 2023-04-01       Email
# 10   CMP-00011       Q4_Launch_CMP-00011        NaT 2023-03-01   Instagram
# ...

# %%
df = pd.read_csv('S:\Python\Python Scripts\DataCleaner\Data_Cleaning_Adv\sample_datasets\marketing_campaign_data_messy.csv')
df = pd.read_csv('Final_Data.csv')
print(df.dtypes)
print(df.isnull().sum())
print(df['channel'].unique())
# Out:
# campaign_id          str
# campaign_name        str
# start_date           str
# end_date             str
# channel              str
# impressions      float64
# clicks           float64
# spend            float64
# conversions      float64
# active               str
# campaign_tag         str
# dtype: object
# campaign_id      0
# campaign_name    0
# start_date       0
# end_date         0
# channel          0
# impressions      0
# clicks           0
# spend            0
# conversions      0
# active           0
# campaign_tag     0
# dtype: int64
# <StringArray>
# [    'Tiktok',   'Facebook',      'Email',  'Instagram', 'Google Ads',
#      'E-Mail',      'Gogle',    'Tik_Tok',    'Facebok', 'Insta_Gram']
# Length: 10, dtype: str
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ACER\AppData\Local\Temp\ipykernel_256\891022078.py:1: SyntaxWarning: invalid escape sequence '\P'
# ...

# %%
pd.read_csv('S:\Python\Python Scripts\DataCleaner\Data_Cleaning_Adv\sample_datasets\marketing_campaign_data_messy.csv').head(50)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ACER\AppData\Local\Temp\ipykernel_256\1697439573.py:1: SyntaxWarning: invalid escape sequence '\P'
#   pd.read_csv('S:\Python\Python Scripts\DataCleaner\Data_Cleaning_Adv\sample_datasets\marketing_campaign_data_messy.csv').head(50)
#     Campaign_ID              Campaign_Name           Start_Date    End_Date  \
# 0      CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1      CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2      CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3      CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4      CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
# 5      CMP-00006  Q4_BlackFriday_CMP-00006  2023-10-15 00:00:00  2023-10-28
# 6      CMP-00007       Q3_Launch_CMP-00007  2023-10-07 00:00:00  2023-10-23
# ...

# %%
pd.read_csv('S:\Python\Python Scripts\DataCleaner\Data_Cleaning_Adv\Final_Data.csv').head(50)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ACER\AppData\Local\Temp\ipykernel_256\3536424345.py:1: SyntaxWarning: invalid escape sequence '\P'
#   pd.read_csv('S:\Python\Python Scripts\DataCleaner\Data_Cleaning_Adv\Final_Data.csv').head(50)
#    campaign_id             campaign_name  start_date    end_date     channel  \
# 0    CMP-00001       Q4_Summer_CMP-00001  2023-11-24  2023-12-13      Tiktok
# 1    CMP-00002       Q1_Launch_CMP-00002  2023-05-06  2023-05-12    Facebook
# 2    CMP-00003       Q3_Winter_CMP-00003  2023-12-13  2023-12-20       Email
# 3    CMP-00004  Q1_BlackFriday_CMP-00004  2023-10-30  2023-11-03      Tiktok
# 4    CMP-00005       Q2_Winter_CMP-00005  2023-04-22  2023-04-23    Facebook
# 5    CMP-00006  Q4_BlackFriday_CMP-00006  2023-10-15  2023-10-28   Instagram
# 6    CMP-00007       Q3_Launch_CMP-00007  2023-10-07  2023-10-23    Facebook
# ...
